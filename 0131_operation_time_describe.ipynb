# %%
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.sans-serif']=['Microsoft YAHEI'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %%
path = './data/data_regression.xlsx'
df = pd.read_excel(path)
df.shape
# Out:
# (3629, 19)

# %%
def operation_time_describe(df):
    desc = {}
    df_group = df.filter(['手术ID','病区','手术时间'])
    for department,group_by_department in df_group.groupby('病区'):
        desc[department] = {}
        desc[department]['min'] = group_by_department['手术时间'].min().round(2)
        desc[department]['max'] = group_by_department['手术时间'].max().round(2)
        desc[department]['avg'] = group_by_department['手术时间'].mean().round(2)
    return desc

# %%
df_operation_time = df['手术时间']
with plt.style.context(['science','grid','notebook']):
    plt.figure(figsize=(8,6))
    plt.hist(df_operation_time, bins=70, density=False,edgecolor="black",color='#00b141')
    
    plt.ylabel('频数',fontdict={'size':14})
    plt.xlabel('手术室占用时长/h',fontdict={'size':14})

    plt.show()

# %%
operation_time_describe(df)
# Out:
# {'口腔科病区': {'min': 0.64, 'max': 11.81, 'avg': 3.39},
#  '妇产科病区': {'min': 0.04, 'max': 13.66, 'avg': 2.13},
#  '心血管病区': {'min': 0.43, 'max': 10.62, 'avg': 4.8},
#  '整形外科病区': {'min': 1.17, 'max': 8.15, 'avg': 4.64},
#  '普通外科病区': {'min': 0.14, 'max': 12.58, 'avg': 3.95},
#  '普通胸外科病区': {'min': 0.54, 'max': 9.06, 'avg': 3.45},
#  '泌尿外科中心病区': {'min': 0.86, 'max': 10.29, 'avg': 2.71},
#  '眼科病区': {'min': 0.81, 'max': 3.98, 'avg': 2.45},
#  '神经内科病区': {'min': 1.36, 'max': 5.68, 'avg': 3.05},
#  '神经外科病区': {'min': 0.67, 'max': 11.52, 'avg': 3.93},
#  '耳鼻咽喉科病区': {'min': 0.16, 'max': 4.71, 'avg': 1.81},
#  '肝胆外科病区': {'min': 0.88, 'max': 10.11, 'avg': 3.08},
#  '骨科病区': {'min': 0.01, 'max': 11.94, 'avg': 3.17}}
